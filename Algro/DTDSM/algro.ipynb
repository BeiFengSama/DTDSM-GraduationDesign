# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))  # 设置画布大小

# %%
# 绘制流程图中的各个步骤或操作
plt.text(0.5, 0.9, 'Step 1: Input Data', ha='center', va='center', fontsize=12, bbox=dict(facecolor='lightgray', alpha=0.5))
plt.arrow(0.5, 0.8, 0, -0.2, head_width=0.05, head_length=0.1, fc='blue', ec='blue')

plt.text(0.5, 0.7, 'Step 2: Preprocessing', ha='center', va='center', fontsize=12, bbox=dict(facecolor='lightgray', alpha=0.5))
plt.arrow(0.5, 0.6, 0, -0.2, head_width=0.05, head_length=0.1, fc='blue', ec='blue')

# 绘制其他步骤...

# 添加文本说明等

# 设置坐标轴属性
plt.axis('off')  # 关闭坐标轴显示
plt.show()
